# %%
# Data cleaning
  # Load data
  # Examine data
  # Drop duplicates
  # Load only necessary data
  # drop null data
  # detect outliers and drop outliers

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('estate.csv', sep=',')
df
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...

# %%
print(df.shape, '\n')

print(df.dtypes)
# Out:
# (923159, 12)
#
# status           object
# price           float64
# bed             float64
# bath            float64
# acre_lot        float64
# full_address     object
# street           object
# city             object
# state            object
# zip_code        float64
# house_size      float64
# sold_date        object
# dtype: object

# %%
# drop duplicates

df.drop_duplicates(subset=['full_address'],inplace = True)
df
# Out:
#           status      price  bed  bath  acre_lot  \
# 0       for_sale   105000.0  3.0   2.0      0.12
# 1       for_sale    80000.0  4.0   2.0      0.08
# 2       for_sale    67000.0  2.0   1.0      0.15
# 3       for_sale   145000.0  4.0   2.0      0.10
# 4       for_sale    65000.0  6.0   2.0      0.05
# ...          ...        ...  ...   ...       ...
# 923135  for_sale  1649000.0  4.0   3.0      0.17
# 923136  for_sale   779000.0  4.0   3.0      0.59
# 923144  for_sale  1595000.0  5.0   4.0      0.16
# 923146  for_sale  4595000.0  4.0   5.0      0.14
# 923147  for_sale  2995000.0  5.0   4.0      0.50
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...

# %%
# drop null values
df = df.dropna()

# double check null values
df.isnull().sum()
# Out:
# status          0
# price           0
# bed             0
# bath            0
# acre_lot        0
# full_address    0
# street          0
# city            0
# state           0
# zip_code        0
# house_size      0
# sold_date       0
# dtype: int64

# %%
# drop unnecessary columns

df = df.drop(columns=['status','full_address','street','city','state','sold_date'])
df
# Out:
#             price  bed  bath  acre_lot  zip_code  house_size
# 829      110000.0  7.0   3.0      0.09     949.0      1192.0
# 10344    950000.0  5.0   4.0      0.99     802.0      5000.0
# 10351   6899000.0  4.0   6.0      0.83     802.0      4600.0
# 24237    525000.0  3.0   3.0      0.45    1001.0      2314.0
# 24238    289900.0  3.0   2.0      0.36    1001.0      1276.0
# ...           ...  ...   ...       ...       ...         ...
# 923135  1649000.0  4.0   3.0      0.17    6807.0      2178.0
# 923136   779000.0  4.0   3.0      0.59   10952.0      1816.0
# 923144  1595000.0  5.0   4.0      0.16    6830.0      2231.0
# 923146  4595000.0  4.0   5.0      0.14    6830.0      4863.0
# 923147  2995000.0  5.0   4.0      0.50    6830.0      3446.0
#
# [32658 rows x 6 columns]

# %%
# Data Exploration
  # Explore data/ notice any outliers?
  # visualization

# %%
# Determine Correlations
import matplotlib.pyplot as plt
import seaborn as sns

correlation_martrix = df.corr(method='pearson')

sns.heatmap(correlation_martrix, annot=True)

plt.title('Correlations')
plt.show()

# %%
reg1 = sns.regplot(x='bed',y='price',data=df,scatter_kws={'color':'red'}, line_kws={'color':'blue'})
plt.title('Number of Beds and Price')
plt.xlabel('Number of Beds')
plt.ylabel('Price')
plt.show()

# %%
reg2 = sns.regplot(x='bath',y='price',data=df,scatter_kws={'color':'black'}, line_kws={'color':'green'})
plt.title('Number of Baths and Price')
plt.xlabel('Number of Baths')
plt.ylabel('Price')
plt.show()

# %%
reg3 = sns.regplot(x='acre_lot',y='price',data=df,scatter_kws={'color':'blue'}, line_kws={'color':'yellow'})
plt.title('Lot Size and Price')
plt.xlabel('Lot Size')
plt.ylabel('Price')
plt.show()

# %%
reg4 = sns.regplot(x='house_size',y='price',data=df,scatter_kws={'color':'pink'}, line_kws={'color':'black'})
plt.title('House Size and Price')
plt.xlabel('House Size')
plt.ylabel('Price')
plt.show()

# %%
# Examine outliers

numeric = ['price', 'bed', 'bath','acre_lot','house_size']
df.boxplot(numeric)
# Out:
# <AxesSubplot:>

# %%
for x in ['price']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

for x in ['bed']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

for x in ['bath']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

for x in ['acre_lot']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

for x in ['house_size']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
# if value is null then it is an outlier

df.isnull().sum()
# Out:
# price         3024
# bed           3059
# bath          2645
# acre_lot      4173
# zip_code         0
# house_size    1963
# dtype: int64

# %%
# drop outliers
df = df.dropna(axis = 0)

# re-examine
df.isnull().sum()
# Out:
# price         0
# bed           0
# bath          0
# acre_lot      0
# zip_code      0
# house_size    0
# dtype: int64

# %%
numeric = ['price', 'bed', 'bath','acre_lot','house_size']
df.boxplot(numeric)
# Out:
# <AxesSubplot:>

# %%
# Re-visualize data without outliers

# %%
# New Correlation score (r value)
import matplotlib.pyplot as plt
import seaborn as sns

correlation_martrix = df.corr(method='pearson')

sns.heatmap(correlation_martrix, annot=True)

plt.title('Correlations')
plt.show()

# %%
reg1 = sns.regplot(x='bed',y='price',data=df,scatter_kws={'color':'red'}, line_kws={'color':'blue'})
plt.title('Number of Beds and Price')
plt.xlabel('Number of Beds')
plt.ylabel('Price')
plt.show()

# %%
reg2 = sns.regplot(x='bath',y='price',data=df,scatter_kws={'color':'black'}, line_kws={'color':'green'})
plt.title('Number of Baths and Price')
plt.xlabel('Number of Baths')
plt.ylabel('Price')
plt.show()

# %%
reg3 = sns.regplot(x='acre_lot',y='price',data=df,scatter_kws={'color':'blue'}, line_kws={'color':'yellow'})
plt.title('Lot Size and Price')
plt.xlabel('Lot Size')
plt.ylabel('Price')
plt.show()

# %%
reg4 = sns.regplot(x='house_size',y='price',data=df,scatter_kws={'color':'pink'}, line_kws={'color':'black'})
plt.title('House Size and Price')
plt.xlabel('House Size')
plt.ylabel('Price')
plt.show()

# %%
bar1 = sns.barplot(data=df, x='bed', y='price')
plt.title('Number of Beds and Price')
plt.xlabel('Number of Beds')
plt.ylabel('Price')
plt.show()

# %%
bar2 = sns.barplot(data=df, x='bed', y='price')
plt.title('Number of Baths and Price')
plt.xlabel('Number of Baths')
plt.ylabel('Price')
plt.show()

# %%
# Model 
    # Data split
    # Model Fitting
    # Cross-validation
    # Confusion Matrix

# %%
# Data preprocessing for modeling
X = df.drop(['price'], axis=1).values
y = df['price'].values

# Data split
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from warnings import simplefilter

simplefilter(action='ignore', category=FutureWarning)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=7, shuffle=True)

# %%
# Make sure shape and data is good

print('x-train: \n',X_train)
print('y-train: \n',y_train)
print('x-test: \n',X_test)
print('y-test: \n',y_test)
# Out:
# x-train:
#  [[3.0000e+00 1.0000e+00 1.8000e-01 4.3640e+03 1.4180e+03]
#  [2.0000e+00 2.0000e+00 2.0000e-02 1.9146e+04 8.5400e+02]
#  [4.0000e+00 3.0000e+00 2.0000e-02 1.9130e+04 2.4630e+03]
#  ...
#  [4.0000e+00 3.0000e+00 1.0000e+00 6.5120e+03 2.3830e+03]
#  [4.0000e+00 4.0000e+00 5.2000e-01 1.0950e+04 2.8580e+03]
#  [3.0000e+00 1.0000e+00 3.0000e-02 1.9120e+04 1.2120e+03]]
# y-train:
#  [234900. 277000. 739000. ... 555000. 879000. 205000.]
# x-test:
#  [[3.0000e+00 3.0000e+00 6.8000e-01 1.8458e+04 3.1040e+03]
#  [3.0000e+00 3.0000e+00 5.0000e-02 1.9301e+04 2.0200e+03]
#  [2.0000e+00 2.0000e+00 4.5000e-01 2.6570e+03 1.2200e+03]
#  ...
#  [3.0000e+00 2.0000e+00 1.4000e-01 1.9067e+04 1.5600e+03]
#  [3.0000e+00 3.0000e+00 1.9000e-01 1.9808e+04 2.8250e+03]
#  [4.0000e+00 3.0000e+00 5.0000e-01 1.9720e+04 2.4000e+03]]
# y-test:
#  [449900. 425000. 949000. ... 309999. 649990. 339900.]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_absolute_error, r2_score

# store model in variable
models = {"Linear Regression": LinearRegression(), 
          "Decision Tree": DecisionTreeRegressor(), 
          "K-Neigbors": KNeighborsRegressor(), 
          "Support Vector Machine": SVR(),
          "Bayesian Ridge Regression": BayesianRidge()
         }

for name, model in models.items():
    # Model fitting (fit train data)
    model.fit(X_train, y_train)
    
    # Test/Evaluate the model. Does it give similar/close values?
    # Predicted values per model
    y_pred = model.predict(X_test)
    
    # Compare actual y vs predicted y
    print(name, 'Actual Price:', y_test)
    print(name, 'Predicted Price:', y_pred, '\n')
# Out:
# Linear Regression Actual Price: [449900. 425000. 949000. ... 309999. 649990. 339900.]
# Linear Regression Predicted Price: [590242.98516804 485953.91337517 397000.0494726  ... 335032.99562458
#  570500.1546488  503371.97121561]
#
# Decision Tree Actual Price: [449900. 425000. 949000. ... 309999. 649990. 339900.]
# Decision Tree Predicted Price: [349999. 375000. 449000. ... 409000. 319900. 490000.]
#
# K-Neigbors Actual Price: [449900. 425000. 949000. ... 309999. 649990. 339900.]
# K-Neigbors Predicted Price: [429539.8 461562.4 535400.  ... 386885.  421979.8 431960. ]
#
# Support Vector Machine Actual Price: [449900. 425000. 949000. ... 309999. 649990. 339900.]
# Support Vector Machine Predicted Price: [368388.27790829 368207.59232097 369888.20994421 ... 368207.81052427
#  368209.08766635 368188.44540631]
#
# Bayesian Ridge Regression Actual Price: [449900. 425000. 949000. ... 309999. 649990. 339900.]
# ...

# %%
models = {"Linear Regression": LinearRegression(), 
          "Decision Tree": DecisionTreeRegressor(), 
          "K-Neigbors": KNeighborsRegressor(), 
          "Support Vector Machine": SVR(),
          "Bayesian Ridge Regression": BayesianRidge()
         }

for name, model in models.items():
    # Model fitting (fit train data)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    # compute Mean Absolute Error: for every data point, how much error is there?
    print(name, "Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    
    # compute R square/ r2 score: range from 0-1. If the model is closer to one, the better it is.
    print(name, "R-squared score:", r2_score(y_test, y_pred), '\n')
# Out:
# Linear Regression Mean Absolute Error: 150674.77157783476
# Linear Regression R-squared score: 0.3481275988725575
#
# Decision Tree Mean Absolute Error: 115519.22443723549
# Decision Tree R-squared score: 0.5293130724944635
#
# K-Neigbors Mean Absolute Error: 109128.48304730012
# K-Neigbors R-squared score: 0.617015884381233
#
# Support Vector Machine Mean Absolute Error: 191000.48614792785
# Support Vector Machine R-squared score: -0.0696889858106522
#
# Bayesian Ridge Regression Mean Absolute Error: 150662.38577764085
# Bayesian Ridge Regression R-squared score: 0.3481316584161368
